# %%
import os
# Deshabilita la GPU
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"  

# Suprime los logs de TensorFlow relacionados con errores e información
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"  

# Suprime las advertencias para una salida más limpia
import warnings
warnings.filterwarnings('ignore')

# Importa TensorFlow y Keras
import tensorflow as tf
import keras

# Imprime las versiones de TensorFlow y Keras instaladas en el entorno
print(f"TensorFlow version: {tf.__version__}")
print(f"Keras version: {keras.__version__}")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1733273833.401981   26382 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1733273833.406976   26382 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# TensorFlow version: 2.18.0
# Keras version: 3.6.0

# %%
# Importación de módulos estándar
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Importación de módulos de Keras para construcción de modelos de redes neuronales
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, UpSampling1D, Flatten, Dense, Reshape, ZeroPadding1D
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy, MeanSquaredError
from tensorflow.keras import metrics
import tensorflow.keras.backend as K


# Importación de módulos de scikit-learn para preprocesamiento y evaluación de modelos
from sklearn.metrics import (classification_report, confusion_matrix,mean_squared_error, recall_score, precision_score, 
                             accuracy_score, f1_score, roc_auc_score)
from sklearn.manifold import TSNE
from sklearn.neighbors import KNeighborsClassifier
from tensorflow.keras.models import load_model



# Importación del módulo time para medir tiempos de ejecución
from time import time

# Configuración de semillas aleatorias para reproducibilidad
np.random.seed(7)
seed = 15
rng = np.random.RandomState(313)

# Configuración para visualizar gráficos en línea en Jupyter Notebook
# %matplotlib inline

# %% [markdown]
# ## Carga de Datos y Preparación de Conjuntos
#
# ### Carga de Datos:
# - **Objetivo**: Leer los datos balanceados para los conjuntos de entrenamiento (`X_train_ae`) y prueba (`X_test_ae`).
# - **Validación**:
#   - Inspeccionar las distribuciones de las clases para confirmar el balance en los datos.
#   - Confirmar las dimensiones de los conjuntos de entrenamiento y prueba después de separar las etiquetas (`CLASS_LABEL`).
#
# ### Separación de Características y Etiquetas:
# - **Objetivo**: Separar las etiquetas (`Y_train_ae`, `Y_test_ae`) de las características (`X_train_ae`, `X_test_ae`) para cada conjunto de datos.
# - **Validación**:
#   - Confirmar que las etiquetas fueron separadas correctamente.
#   - Validar que las dimensiones de las características coinciden con lo esperado.
#
# ## Resultados Observados
#
# ### Carga de Datos:
# #### Entrenamiento:
# - **Distribución de Clases y Porcentajes**:
#   - Clase `0`: **6,212** instancias (50.06%).
#   - Clase `1`: **6,196** instancias (49.94%).
# - **Dimensiones**:
#   - `X_train_ae`: **(12,408, 606)** (características).
#   - `Y_train_ae`: **(12,408,)** (etiquetas).
#
# #### Prueba:
# - **Distribución de Clases y Porcentajes**:
#   - Clase `0`: **777** instancias (50.10%).
#   - Clase `1`: **774** instancias (49.90%).
# - **Dimensiones**:
#   - `X_test_ae`: **(1,551, 606)** (características).
#   - `Y_test_ae`: **(1,551,)** (etiquetas).
#
# ### Separación de Características y Etiquetas:
# #### Entrenamiento:
# - Las etiquetas (`CLASS_LABEL`) fueron eliminadas del conjunto `X_train_ae`.
# - **Dimensiones Finales**:
#   - `X_train_ae`: **(12,408, 606)**.
#   - `Y_train_ae`: **(12,408,)**.
#
# #### Prueba:
# - Las etiquetas (`CLASS_LABEL`) fueron eliminadas del conjunto `X_test_ae`.
# - **Dimensiones Finales**:
#   - `X_test_ae`: **(1,551, 606)**.
#   - `Y_test_ae`: **(1,551,)**.

# %%
X_train_ae = pd.read_csv(r"../Datos/BinarioTrainBalanced.csv")
X_test_ae  = pd.read_csv(r"../Datos/BinarioTest1Balanced.csv")

# %%
print("\n\t\tDatos de entrenamiento")
nr_clases = X_train_ae['CLASS_LABEL'].value_counts(sort=True)
print("\nCantidad ",nr_clases,"\nPorcentajes", nr_clases*100/X_train_ae.shape[0])
Y_train_ae = X_train_ae['CLASS_LABEL']
X_train_ae = X_train_ae.drop(['CLASS_LABEL'], axis=1)
print(X_train_ae.shape, Y_train_ae.shape)

print("\n\t\tDatos de prueba AE")
nr_clases = X_test_ae['CLASS_LABEL'].value_counts(sort=True)
print("\nCantidad ",nr_clases,"\nPorcentajes", nr_clases*100/X_test_ae.shape[0])
Y_test_ae = X_test_ae['CLASS_LABEL']
X_test_ae = X_test_ae.drop(['CLASS_LABEL'], axis=1)
print(X_test_ae.shape, Y_test_ae.shape)
# Out:
# 		Datos de entrenamiento
#
# Cantidad  CLASS_LABEL
# 0    6212
# 1    6196
# Name: count, dtype: int64
# Porcentajes CLASS_LABEL
# 0    50.064475
# 1    49.935525
# Name: count, dtype: float64
# (12408, 606) (12408,)
#
# 		Datos de prueba AE
#
# Cantidad  CLASS_LABEL
# 0    777
# 1    774
# Name: count, dtype: int64
# Porcentajes CLASS_LABEL
# 0    50.096712
# 1    49.903288
# Name: count, dtype: float64
# (1551, 606) (1551,)

# %%
X_train = X_train_ae.to_numpy().reshape((X_train_ae.shape[0], X_train_ae.shape[1], 1))
X_test = X_test_ae.to_numpy().reshape((X_test_ae.shape[0], X_test_ae.shape[1], 1))

# Verificar las dimensiones de las entradas redimensionadas
print("Dimensión de X_train después de redimensionar:", X_train.shape)
print("Dimensión de X_test después de redimensionar:", X_test.shape)
# Out:
# Dimensión de X_train después de redimensionar: (12408, 606, 1)
# Dimensión de X_test después de redimensionar: (1551, 606, 1)

# %% [markdown]
# ## Construcción y Configuración del Modelo

# %%
from tensorflow.keras import backend as K

def r2_score(y_true, y_pred):
    # Asegurarse de que las dimensiones sean consistentes
    y_true = K.flatten(y_true)
    y_pred = K.flatten(y_pred)
    ss_res = K.sum(K.square(y_true - y_pred))
    ss_tot = K.sum(K.square(y_true - K.mean(y_true)))
    return 1 - ss_res / (ss_tot + K.epsilon())

# %%
# Definir la entrada explícita del modelo
input_shape = (606, 1)  # Ajustar al número de características y canales
entrada = Input(shape=input_shape, name="input_layer")

# Encoder
x = Conv1D(
    filters=96,  # Basado en la salida esperada
    kernel_size=3,  # Ajusta según tus datos
    activation='relu',
    padding='same',
    name="encoder_conv1"
)(entrada)
x = MaxPooling1D(pool_size=2, padding='same', name="encoder_pool1")(x)

x = Conv1D(
    filters=64,  # Basado en la salida esperada
    kernel_size=3,  # Ajusta según tus datos
    activation='relu',
    padding='same',
    name="encoder_conv2"
)(x)
x = MaxPooling1D(pool_size=2, padding='same', name="encoder_pool2")(x)

x = Flatten(name="flatten")(x)  # Salida esperada: (None, 9728)
x = Dense(units=5000, activation='relu', name="dense1")(x)
x = Dense(units=1000, activation='relu', name="dense2")(x)
x = Dense(units=100, activation='relu', name="dense3")(x)

latent_space = Dense(units=20, activation='relu', name="latent_space")(x)

# Decoder
x = Dense(units=100, activation='relu', name="dense4")(latent_space)
x = Dense(units=1000, activation='relu', name="dense5")(x)
x = Dense(units=5000, activation='relu', name="dense6")(x)

x = Dense(units=(151 * 64), activation='relu', name="dense7")(x)  # Salida esperada: (None, 9664)
x = Reshape((151, 64), name="reshape")(x)

x = Conv1D(
    filters=64,
    kernel_size=3,
    activation='relu',
    padding='same',
    name="decoder_conv1"
)(x)
x = UpSampling1D(size=2, name="upsample1")(x)

x = Conv1D(
    filters=96,
    kernel_size=3,
    activation='relu',
    padding='same',
    name="decoder_conv2"
)(x)
x = UpSampling1D(size=2, name="upsample2")(x)

# Salida
salida = Conv1D(filters=1, kernel_size=1, activation='linear', padding='same', name="output_conv")(x)
salida = ZeroPadding1D(padding=(1, 1), name="output_AE")(salida)

# Clasificador
classifier = Dense(10, activation='relu', name="classifier_hidden")(latent_space)
classifier_output = Dense(1, activation='sigmoid', name="output_classifier")(classifier)

# Construir el modelo
autoencoder = Model(inputs=entrada, outputs=[salida, classifier_output])

# %%
# Compilación del modelo
autoencoder.compile(
    optimizer=Adam(learning_rate=0.001),
    loss={
        "output_AE": "mse",
        "output_classifier": 'binary_crossentropy'
    },
   loss_weights={
       "output_AE": 0.5,  # Peso para la reconstrucción
       "output_classifier": 1.0  # Peso para la clasificación
   },
    metrics={
        "output_AE": ['mae', r2_score],
        "output_classifier": [metrics.BinaryAccuracy(),
                              metrics.Recall(),
                              metrics.Precision(),
                              metrics.AUC()]
    }
)

# Resumen del modelo
autoencoder.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 606, 1)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_conv1       │ (None, 606, 96)   │        384 │ input_layer[0][0] │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_pool1       │ (None, 303, 96)   │          0 │ encoder_conv1[0]… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_conv2       │ (None, 303, 64)   │     18,496 │ encoder_pool1[0]… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_pool2       │ (None, 152, 64)   │          0 │ encoder_conv2[0]… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 9728)      │          0 │ encoder_pool2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense1 (Dense)      │ (None, 5000)      │ 48,645,000 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense2 (Dense)      │ (None, 1000)      │  5,001,000 │ dense1[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense3 (Dense)      │ (None, 100)       │    100,100 │ dense2[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ latent_space        │ (None, 20)        │      2,020 │ dense3[0][0]      │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense4 (Dense)      │ (None, 100)       │      2,100 │ latent_space[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense5 (Dense)      │ (None, 1000)      │    101,000 │ dense4[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense6 (Dense)      │ (None, 5000)      │  5,005,000 │ dense5[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense7 (Dense)      │ (None, 9664)      │ 48,329,664 │ dense6[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 151, 64)   │          0 │ dense7[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_conv1       │ (None, 151, 64)   │     12,352 │ reshape[0][0]     │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ upsample1           │ (None, 302, 64)   │          0 │ decoder_conv1[0]… │
# │ (UpSampling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_conv2       │ (None, 302, 96)   │     18,528 │ upsample1[0][0]   │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ upsample2           │ (None, 604, 96)   │          0 │ decoder_conv2[0]… │
# │ (UpSampling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output_conv         │ (None, 604, 1)    │         97 │ upsample2[0][0]   │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ classifier_hidden   │ (None, 10)        │        210 │ latent_space[0][… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output_AE           │ (None, 606, 1)    │          0 │ output_conv[0][0] │
# │ (ZeroPadding1D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output_classifier   │ (None, 1)         │         11 │ classifier_hidde… │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 107,235,962 (409.07 MB)
#  Trainable params: 107,235,962 (409.07 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.python.keras.utils.vis_utils import plot_model
import pydot
tf.keras.utils.plot_model(autoencoder, 
                        to_file='custom_model.png',
                        show_shapes=True,
                        show_layer_names=True,
                        dpi=50,                    
                        rankdir='AB'                 
                    )

# %% [markdown]
# ## Verificación de Formas de Entrada y Salida del Modelo

# %%
print(f"Forma de X_train_ae (input): {X_train.shape}")  # (12408, 606)
print(f"Forma de Y_train_ae (labels): {Y_train_ae.shape}")  # (12408, 1)
print(f"Forma esperada para output_layer: {autoencoder.output[0].shape}")  # (None, 606)
print(f"Forma esperada para classifier_output: {autoencoder.output[1].shape}")  # (None, 1)
autoencoder.output_names
# Out:
# Forma de X_train_ae (input): (12408, 606, 1)
# Forma de Y_train_ae (labels): (12408,)
# Forma esperada para output_layer: (None, 606, 1)
# Forma esperada para classifier_output: (None, 1)
# ListWrapper(['output_AE', 'output_classifier'])

# %%
Y_ae = (X_train, Y_train_ae)

# Imprimir información sobre train_y
print("Tamaños de train_y:")
print(f"  Y_ae: {len(Y_ae)}")  
print(f"  Y_train_ae: {Y_ae[0].shape}")    
print(f"  Y_train_ae: {Y_ae[1].shape}")
# Out:
# Tamaños de train_y:
#   Y_ae: 2
#   Y_train_ae: (12408, 606, 1)
#   Y_train_ae: (12408,)

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Definir EarlyStopping
early_stopping = EarlyStopping(
    monitor='val_loss',    # Métrica que se observará (por ejemplo, 'val_loss')
    patience=10,            # Número de épocas sin mejora antes de detener
    restore_best_weights=True  # Restaurar los pesos de la mejor época
)

# Entrenamiento con EarlyStopping
history = autoencoder.fit(
    x=X_train,
    y=Y_ae,
    batch_size=128,
    epochs=100,
    validation_split=0.2,
    verbose=2,
    callbacks=[early_stopping]  # Pasar EarlyStopping en los callbacks
)
# Out:
# Epoch 1/100
# 78/78 - 73s - 937ms/step - loss: 0.6007 - output_AE_loss: 0.0076 - output_AE_mae: 0.0593 - output_AE_r2_score: 0.9099 - output_classifier_auc: 0.7266 - output_classifier_binary_accuracy: 0.6471 - output_classifier_loss: 0.5924 - output_classifier_precision: 0.6342 - output_classifier_recall: 0.6964 - val_loss: 0.4497 - val_output_AE_loss: 0.0019 - val_output_AE_mae: 0.0384 - val_output_AE_r2_score: 0.9768 - val_output_classifier_auc: 0.8902 - val_output_classifier_binary_accuracy: 0.7877 - val_output_classifier_loss: 0.4439 - val_output_classifier_precision: 0.8799 - val_output_classifier_recall: 0.6615
# Epoch 2/100
# 78/78 - 69s - 884ms/step - loss: 0.4302 - output_AE_loss: 0.0022 - output_AE_mae: 0.0398 - output_AE_r2_score: 0.9742 - output_classifier_auc: 0.8828 - output_classifier_binary_accuracy: 0.7949 - output_classifier_loss: 0.4276 - output_classifier_precision: 0.7955 - output_classifier_recall: 0.7942 - val_loss: 0.4108 - val_output_AE_loss: 0.0027 - val_output_AE_mae: 0.0445 - val_output_AE_r2_score: 0.9675 - val_output_classifier_auc: 0.9175 - val_output_classifier_binary_accuracy: 0.8171 - val_output_classifier_loss: 0.4040 - val_output_classifier_precision: 0.9320 - val_output_classifier_recall: 0.6802
# Epoch 3/100
# 78/78 - 69s - 891ms/step - loss: 0.2054 - output_AE_loss: 0.0011 - output_AE_mae: 0.0293 - output_AE_r2_score: 0.9872 - output_classifier_auc: 0.9728 - output_classifier_binary_accuracy: 0.9169 - output_classifier_loss: 0.2042 - output_classifier_precision: 0.9373 - output_classifier_recall: 0.8937 - val_loss: 0.2125 - val_output_AE_loss: 0.0011 - val_output_AE_mae: 0.0300 - val_output_AE_r2_score: 0.9865 - val_output_classifier_auc: 0.9794 - val_output_classifier_binary_accuracy: 0.9114 - val_output_classifier_loss: 0.2092 - val_output_classifier_precision: 0.9809 - val_output_classifier_recall: 0.8373
# Epoch 18/100
# 78/78 - 70s - 894ms/step - loss: 0.2145 - output_AE_loss: 0.0011 - output_AE_mae: 0.0296 - output_AE_r2_score: 0.9868 - output_classifier_auc: 0.9709 - output_classifier_binary_accuracy: 0.9101 - output_classifier_loss: 0.2129 - output_classifier_precision: 0.9301 - output_classifier_recall: 0.8871 - val_loss: 0.1977 - val_output_AE_loss: 0.0011 - val_output_AE_mae: 0.0296 - val_output_AE_r2_score: 0.9869 - val_output_classifier_auc: 0.9778 - val_output_classifier_binary_accuracy: 0.9194 - val_output_classifier_loss: 0.1950 - val_output_classifier_precision: 0.9509 - val_output_classifier_recall: 0.8828
# Epoch 19/100
# 78/78 - 70s - 892ms/step - loss: 0.2127 - output_AE_loss: 0.0010 - output_AE_mae: 0.0289 - output_AE_r2_score: 0.9876 - output_classifier_auc: 0.9712 - output_classifier_binary_accuracy: 0.9109 - output_classifier_loss: 0.2116 - output_classifier_precision: 0.9330 - output_classifier_recall: 0.8856 - val_loss: 0.1838 - val_output_AE_loss: 0.0010 - val_output_AE_mae: 0.0286 - val_output_AE_r2_score: 0.9878 - val_output_classifier_auc: 0.9792 - val_output_classifier_binary_accuracy: 0.9243 - val_output_classifier_loss: 0.1818 - val_output_classifier_precision: 0.9468 - val_output_classifier_recall: 0.8975
# Epoch 20/100
# 78/78 - 69s - 890ms/step - loss: 0.2123 - output_AE_loss: 0.0010 - output_AE_mae: 0.0288 - output_AE_r2_score: 0.9876 - output_classifier_auc: 0.9722 - output_classifier_binary_accuracy: 0.9112 - output_classifier_loss: 0.2111 - output_classifier_precision: 0.9249 - output_classifier_recall: 0.8953 - val_loss: 0.1899 - val_output_AE_loss: 9.4313e-04 - val_output_AE_mae: 0.0277 - val_output_AE_r2_score: 0.9888 - val_output_classifier_auc: 0.9772 - val_output_classifier_binary_accuracy: 0.9174 - val_output_classifier_loss: 0.1880 - val_output_classifier_precision: 0.9317 - val_output_classifier_recall: 0.8991
# Epoch 21/100
# 78/78 - 70s - 892ms/step - loss: 0.1895 - output_AE_loss: 9.6992e-04 - output_AE_mae: 0.0280 - output_AE_r2_score: 0.9885 - output_classifier_auc: 0.9773 - output_classifier_binary_accuracy: 0.9196 - output_classifier_loss: 0.1885 - output_classifier_precision: 0.9344 - output_classifier_recall: 0.9028 - val_loss: 0.1910 - val_output_AE_loss: 9.4187e-04 - val_output_AE_mae: 0.0275 - val_output_AE_r2_score: 0.9888 - val_output_classifier_auc: 0.9782 - val_output_classifier_binary_accuracy: 0.9222 - val_output_classifier_loss: 0.1879 - val_output_classifier_precision: 0.9576 - val_output_classifier_recall: 0.8820
# Epoch 36/100
# 78/78 - 70s - 894ms/step - loss: 0.1190 - output_AE_loss: 9.2010e-04 - output_AE_mae: 0.0273 - output_AE_r2_score: 0.9890 - output_classifier_auc: 0.9908 - output_classifier_binary_accuracy: 0.9529 - output_classifier_loss: 0.1179 - output_classifier_precision: 0.9626 - output_classifier_recall: 0.9424 - val_loss: 0.1915 - val_output_AE_loss: 8.6773e-04 - val_output_AE_mae: 0.0266 - val_output_AE_r2_score: 0.9897 - val_output_classifier_auc: 0.9811 - val_output_classifier_binary_accuracy: 0.9275 - val_output_classifier_loss: 0.1930 - val_output_classifier_precision: 0.9781 - val_output_classifier_recall: 0.8731
# Epoch 37/100
# 78/78 - 70s - 895ms/step - loss: 0.1149 - output_AE_loss: 9.1932e-04 - output_AE_mae: 0.0274 - output_AE_r2_score: 0.9891 - output_classifier_auc: 0.9912 - output_classifier_binary_accuracy: 0.9565 - output_classifier_loss: 0.1140 - output_classifier_precision: 0.9682 - output_classifier_recall: 0.9440 - val_loss: 0.1721 - val_output_AE_loss: 8.7854e-04 - val_output_AE_mae: 0.0267 - val_output_AE_r2_score: 0.9895 - val_output_classifier_auc: 0.9837 - val_output_classifier_binary_accuracy: 0.9303 - val_output_classifier_loss: 0.1721 - val_output_classifier_precision: 0.9171 - val_output_classifier_recall: 0.9447
# Epoch 38/100
# 78/78 - 71s - 904ms/step - loss: 0.1138 - output_AE_loss: 9.0994e-04 - output_AE_mae: 0.0273 - output_AE_r2_score: 0.9892 - output_classifier_auc: 0.9914 - output_classifier_binary_accuracy: 0.9570 - output_classifier_loss: 0.1127 - output_classifier_precision: 0.9682 - output_classifier_recall: 0.9450 - val_loss: 0.1727 - val_output_AE_loss: 8.9853e-04 - val_output_AE_mae: 0.0271 - val_output_AE_r2_score: 0.9893 - val_output_classifier_auc: 0.9826 - val_output_classifier_binary_accuracy: 0.9319 - val_output_classifier_loss: 0.1758 - val_output_classifier_precision: 0.9302 - val_output_classifier_recall: 0.9325
# Epoch 39/100
# 78/78 - 71s - 907ms/step - loss: 0.1104 - output_AE_loss: 9.2679e-04 - output_AE_mae: 0.0275 - output_AE_r2_score: 0.9890 - output_classifier_auc: 0.9919 - output_classifier_binary_accuracy: 0.9577 - output_classifier_loss: 0.1092 - output_classifier_precision: 0.9664 - output_classifier_recall: 0.9485 - val_loss: 0.1713 - val_output_AE_loss: 9.2257e-04 - val_output_AE_mae: 0.0274 - val_output_AE_r2_score: 0.9890 - val_output_classifier_auc: 0.9831 - val_output_classifier_binary_accuracy: 0.9400 - val_output_classifier_loss: 0.1704 - val_output_classifier_precision: 0.9787 - val_output_classifier_recall: 0.8983
# Epoch 40/100
# 78/78 - 71s - 906ms/step - loss: 0.1034 - output_AE_loss: 9.1150e-04 - output_AE_mae: 0.0272 - output_AE_r2_score: 0.9892 - output_classifier_auc: 0.9928 - output_classifier_binary_accuracy: 0.9620 - output_classifier_loss: 0.1024 - output_classifier_precision: 0.9728 - output_classifier_recall: 0.9507 - val_loss: 0.1800 - val_output_AE_loss: 9.6645e-04 - val_output_AE_mae: 0.0282 - val_output_AE_r2_score: 0.9885 - val_output_classifier_auc: 0.9816 - val_output_classifier_binary_accuracy: 0.9299 - val_output_classifier_loss: 0.1828 - val_output_classifier_precision: 0.9251 - val_output_classifier_recall: 0.9341
# Epoch 41/100
# 78/78 - 71s - 907ms/step - loss: 0.0914 - output_AE_loss: 9.0487e-04 - output_AE_mae: 0.0272 - output_AE_r2_score: 0.9892 - output_classifier_auc: 0.9944 - output_classifier_binary_accuracy: 0.9657 - output_classifier_loss: 0.0902 - output_classifier_precision: 0.9736 - output_classifier_recall: 0.9575 - val_loss: 0.1883 - val_output_AE_loss: 8.9591e-04 - val_output_AE_mae: 0.0271 - val_output_AE_r2_score: 0.9893 - val_output_classifier_auc: 0.9821 - val_output_classifier_binary_accuracy: 0.9327 - val_output_classifier_loss: 0.1850 - val_output_classifier_precision: 0.9691 - val_output_classifier_recall: 0.8926
# Epoch 42/100
# 78/78 - 71s - 906ms/step - loss: 0.1077 - output_AE_loss: 9.6664e-04 - output_AE_mae: 0.0280 - output_AE_r2_score: 0.9885 - output_classifier_auc: 0.9923 - output_classifier_binary_accuracy: 0.9577 - output_classifier_loss: 0.1067 - output_classifier_precision: 0.9646 - output_classifier_recall: 0.9503 - val_loss: 0.1869 - val_output_AE_loss: 9.2391e-04 - val_output_AE_mae: 0.0275 - val_output_AE_r2_score: 0.9890 - val_output_classifier_auc: 0.9808 - val_output_classifier_binary_accuracy: 0.9343 - val_output_classifier_loss: 0.1886 - val_output_classifier_precision: 0.9750 - val_output_classifier_recall: 0.8902
# Epoch 43/100
# 78/78 - 71s - 906ms/step - loss: 0.0903 - output_AE_loss: 9.1026e-04 - output_AE_mae: 0.0272 - output_AE_r2_score: 0.9892 - output_classifier_auc: 0.9946 - output_classifier_binary_accuracy: 0.9647 - output_classifier_loss: 0.0890 - output_classifier_precision: 0.9743 - output_classifier_recall: 0.9547 - val_loss: 0.1757 - val_output_AE_loss: 8.8249e-04 - val_output_AE_mae: 0.0269 - val_output_AE_r2_score: 0.9895 - val_output_classifier_auc: 0.9834 - val_output_classifier_binary_accuracy: 0.9351 - val_output_classifier_loss: 0.1735 - val_output_classifier_precision: 0.9734 - val_output_classifier_recall: 0.8934

# %% [markdown]
# ### Evaluación del Modelo Entrenado
#
# Se evalúa el rendimiento del modelo entrenado en los conjuntos de entrenamiento, validación y prueba para medir su precisión, capacidad de reconstrucción y discriminación entre clases.
#
# - **Pesos de las Pérdidas**:
#   - Reconstrucción: **1.0**.
#   - Clasificación: **0.1**.
#
# #### Resumen de Desempeño
# | **Métrica**                  | **Entrenamiento** | **Validación** | **Prueba** |
# |------------------------------|-------------------|----------------|------------|
# | **Pérdida Total (`MSE + CE`)**| 0.0241            | 0.0256         | 0.0231     |
# | **Reconstrucción (`MSE`)**   | 0.0010            | 0.0009         | 0.0011     |
# | **MAE (Reconstrucción)**     | 0.0220            | 0.0202         | 0.0222     |
# | **R² Score (Reconstrucción)**| 0.9938            | 0.9949         | 0.9937     |
# | **Clasificación (`CE`)**     | 0.0230            | 0.0246         | 0.0219     |
# | **AUC (Clasificación)**      | 0.8938            | 0.9692         | 0.9147     |
# | **Exactitud (`Accuracy`)**   | 96.77%            | 89.40%         | 97.08%     |
# | **Precisión (`Precision`)**  | 90.79%            | 86.21%         | 90.65%     |
# | **Sensibilidad (`Recall`)**  | 90.17%            | 93.57%         | 91.04%     |
#
#
# #### Observaciones
# 1. **Reconstrucción (Autoencoder)**:
#    - El modelo muestra una baja pérdida de reconstrucción en todos los conjuntos, con un MAE de alrededor de 0.02. Esto sugiere que el modelo puede reconstruir las entradas de manera precisa.
#    - El R² Score cercano a 0.99 indica una excelente capacidad para capturar la variabilidad en los datos de entrada.
#
# 2. **Rendimiento en Clasificación**:
#    - La pérdida de clasificación (Loss_Cls) es consistente entre los conjuntos de entrenamiento, validación y prueba, lo que demuestra la capacidad del modelo para generalizar.
#    - AUC alto en todos los conjuntos (>0.89) confirma una excelente capacidad del modelo para discriminar entre clases.
#
# 3. **Balance entre Precisión y Sensibilidad**:
#    - El modelo mantiene un buen equilibrio entre precisión y sensibilidad, lo que indica un rendimiento robusto incluso en validación y prueba.
#
# 4. **Diferencia en Exactitud**:
#    - La exactitud en validación (89.40%) es ligeramente inferior a la de los otros conjuntos, lo cual es esperado. Sin embargo, la alta exactitud en prueba (97.08%) confirma la generalización adecuada.
#
# Este análisis confirma que el modelo tiene un excelente desempeño tanto en tareas de reconstrucción como de clasificación. Es robusto, generaliza bien y puede ser aplicado en tareas de clasificación binaria con datos balanceados.

# %%
# Definir las métricas configuradas en el modelo
metricas = [
    "loss",  # Pérdida total
    "output_AE_loss",  # Pérdida del autoencoder
    "output_classifier_loss",  # Pérdida del clasificador
    "output_AE_mae",  # MAE del autoencoder
    "output_AE_r2_score",  # R2 Score del autoencoder
    "output_classifier_binary_accuracy",  # Exactitud del clasificador
    "output_classifier_recall",  # Recall del clasificador
    "output_classifier_precision",  # Precisión del clasificador
    "output_classifier_auc"  # AUC del clasificador
]

# Evaluar el modelo en el conjunto de entrenamiento
train_metrics = autoencoder.evaluate(
    x=X_train_ae,
    y={"output_AE": X_train_ae, "output_classifier": Y_train_ae},
    verbose=1
)

# Mostrar las métricas
print("\nMétricas del Modelo en el Conjunto de Entrenamiento:")
print("-" * 50)

for nombre, valor in zip(metricas, train_metrics):
    print(f"{nombre}: {valor:.6f}")
# Out:
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 12s 29ms/step - loss: 0.1080 - output_AE_loss: 8.8505e-04 - output_AE_mae: 0.0269 - output_AE_r2_score: 0.9895 - output_classifier_auc: 0.9924 - output_classifier_binary_accuracy: 0.9599 - output_classifier_loss: 0.1071 - output_classifier_precision: 0.9763 - output_classifier_recall: 0.9419
#
# Métricas del Modelo en el Conjunto de Entrenamiento:
# --------------------------------------------------
# loss: 0.118284
# output_AE_loss: 0.000891
# output_classifier_loss: 0.117359
# output_AE_mae: 0.027001
# output_AE_r2_score: 0.989393
# output_classifier_binary_accuracy: 0.990936
# output_classifier_recall: 0.955110
# output_classifier_precision: 0.976347
# output_classifier_auc: 0.932698

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'output_AE_loss', 'output_AE_mae', 'output_AE_r2_score', 'output_classifier_auc', 'output_classifier_binary_accuracy', 'output_classifier_loss', 'output_classifier_precision', 'output_classifier_recall', 'val_loss', 'val_output_AE_loss', 'val_output_AE_mae', 'val_output_AE_r2_score', 'val_output_classifier_auc', 'val_output_classifier_binary_accuracy', 'val_output_classifier_loss', 'val_output_classifier_precision', 'val_output_classifier_recall'])

# %%
# Acceder al historial del entrenamiento
history_data = history.history

# Obtener las métricas de la última época
val_loss = history_data["val_loss"][-1]
val_ae_loss = history_data["val_output_AE_loss"][-1]
val_classifier_loss = history_data["val_output_classifier_loss"][-1]
val_ae_mae = history_data["val_output_AE_mae"][-1]
val_ae_r2_score = history_data["val_output_AE_r2_score"][-1]
val_classifier_auc = history_data["val_output_classifier_auc"][-1]
val_classifier_binary_accuracy = history_data["val_output_classifier_binary_accuracy"][-1]
val_classifier_precision = history_data["val_output_classifier_precision"][-1]
val_classifier_recall = history_data["val_output_classifier_recall"][-1]

# Simular una salida de métricas estilo Keras
print(f"\n{len(X_train_ae)}/{len(X_train_ae)} \033[32m━━━━━━━━━━━━━━━━━━━━\033[0m\033[37m\033[0m \033[1m0s\033[0m - "
      f"loss: {val_loss:.4f} - "
      f"output_AE_loss: {val_ae_loss:.4f} - "
      f"output_AE_mae: {val_ae_mae:.4f} - "
      f"output_AE_r2_score: {val_ae_r2_score:.4f} - "
      f"output_classifier_auc: {val_classifier_auc:.4f} - "
      f"output_classifier_binary_accuracy: {val_classifier_binary_accuracy:.4f} - "
      f"output_classifier_loss: {val_classifier_loss:.4f} - "
      f"output_classifier_precision: {val_classifier_precision:.4f} - "
      f"output_classifier_recall: {val_classifier_recall:.4f}")

# Mostrar las métricas al estilo solicitado
print("\nMétricas del Modelo en el Conjunto de Validación:")
print("-" * 50)
print(f"loss: {val_loss:.6f}")
print(f"output_AE_loss: {val_ae_loss:.6f}")
print(f"output_classifier_loss: {val_classifier_loss:.6f}")
print(f"output_AE_mae: {val_ae_mae:.6f}")
print(f"output_AE_r2_score: {val_ae_r2_score:.6f}")
print(f"output_classifier_auc: {val_classifier_auc:.6f}")
print(f"output_classifier_binary_accuracy: {val_classifier_binary_accuracy:.6f}")
print(f"output_classifier_precision: {val_classifier_precision:.6f}")
print(f"output_classifier_recall: {val_classifier_recall:.6f}")
# Out:
# 12408/12408 ━━━━━━━━━━━━━━━━━━━━ 0s - loss: 0.1757 - output_AE_loss: 0.0009 - output_AE_mae: 0.0269 - output_AE_r2_score: 0.9895 - output_classifier_auc: 0.9834 - output_classifier_binary_accuracy: 0.9351 - output_classifier_loss: 0.1735 - output_classifier_precision: 0.9734 - output_classifier_recall: 0.8934
#
# Métricas del Modelo en el Conjunto de Validación:
# --------------------------------------------------
# loss: 0.175748
# output_AE_loss: 0.000882
# output_classifier_loss: 0.173481
# output_AE_mae: 0.026874
# output_AE_r2_score: 0.989481
# output_classifier_auc: 0.983434
# output_classifier_binary_accuracy: 0.935133
# output_classifier_precision: 0.973404
# output_classifier_recall: 0.893409

# %%
# Definir los datos de validación
X_val_ae = X_test_ae
Y_val_ae = {"output_AE": X_test_ae, "output_classifier": Y_test_ae}


# Evaluar el modelo en el conjunto de validación
val_metrics = autoencoder.evaluate(x=X_val_ae, y=Y_val_ae, verbose=0)


# Mostrar las métricas de validación en el formato solicitado
print("\nMétricas del Modelo en el Conjunto de Prueba:")
print("-" * 50)
for nombre, valor in zip(metricas, val_metrics):
    print(f"{nombre}: {valor:.6f}")
# Out:
# Métricas del Modelo en el Conjunto de Prueba:
# --------------------------------------------------
# loss: 0.165495
# output_AE_loss: 0.000889
# output_classifier_loss: 0.163236
# output_AE_mae: 0.026996
# output_AE_r2_score: 0.989437
# output_classifier_binary_accuracy: 0.983471
# output_classifier_recall: 0.932947
# output_classifier_precision: 0.944297
# output_classifier_auc: 0.919897

# %%
import matplotlib.pyplot as plt

def plot_metric(history, metric):
    """
    Grafica una métrica específica del historial de entrenamiento.
    
    Parámetros:
        history (History): El historial de entrenamiento del modelo.
        metric (str): El nombre de la métrica a graficar.
    """
    if metric not in history.history:
        print(f"Métrica '{metric}' no encontrada en el historial.")
        return
    
    epochs = range(1, len(history.history[metric]) + 1)

    # Graficar métrica de entrenamiento
    plt.figure(figsize=(6, 3))
    plt.plot(epochs, history.history[metric], label=f'Train {metric}')
    
    # Graficar métrica de validación si está disponible
    val_metric = f'val_{metric}'
    if val_metric in history.history:
        plt.plot(epochs, history.history[val_metric], label=f'Validation {metric}')
    
    # Configuración del gráfico
    plt.title(f'{metric.replace("_", " ").title()} Vs Epocas')
    plt.xlabel('Epocas')
    plt.ylabel(metric.split("_")[-1].capitalize())  # Usar la última parte como nombre del eje Y
    plt.legend()
    plt.grid()
    plt.show()

# %%
# Llamadas a la función para graficar métricas específicas
plot_metric(history, 'loss')  # Pérdida total
plot_metric(history, 'output_AE_loss')  # Pérdida del autoencoder
plot_metric(history, 'output_AE_mae')  # MAE del autoencoder
plot_metric(history, 'output_AE_r2_score')  # R² Score del autoencoder
plot_metric(history, 'output_classifier_accuracy')  # Precisión del clasificador
plot_metric(history, 'output_classifier_loss')  # Pérdida del clasificador
plot_metric(history, 'output_classifier_precision')  # Precisión del clasificador
plot_metric(history, 'output_classifier_recall')  # Recall del clasificador
plot_metric(history, 'output_classifier_auc')  # AUC del clasificador
# Out:
# Métrica 'output_classifier_accuracy' no encontrada en el historial.

# %%
# Guardar el modelo reentrenado
autoencoder.save("../Modelos/Binary_AE_MPL_SS.keras")
print("Modelo reentrenado guardado exitosamente.")
# Out:
# Modelo reentrenado guardado exitosamente.

# %% [markdown]
# ## Visualizacion de recontrucción

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Función para visualizar la reconstrucción de una señal específica
def visualizar_reconstruccion(autoencoder, datos_originales, indice):
    """
    Visualiza una señal original y su reconstrucción realizada por el autoencoder.
    
    Parámetros:
    - autoencoder: El modelo autoencoder entrenado.
    - datos_originales: Conjunto de datos original (DataFrame o array).
    - indice: Índice de la señal a visualizar (fila del conjunto de datos).
    """
    # Asegurarse de que los datos son un array NumPy
    if isinstance(datos_originales, pd.DataFrame):
        datos_originales = datos_originales.values  # Convertir DataFrame a array si es necesario
    
    # Validar el índice
    if indice < 0 or indice >= datos_originales.shape[0]:
        raise ValueError(f"Índice fuera de rango. Debe estar entre 0 y {datos_originales.shape[0] - 1}.")
    
    # Obtener la señal original (fila)
    señal_original = datos_originales[indice]
    
    # Reconstruir la señal usando la salida del autoencoder correspondiente al reconstructor
    reconstrucciones = autoencoder.predict(señal_original.reshape(1, -1), verbose=0)
    señal_reconstruida = reconstrucciones[0]  # La primera salida corresponde a la reconstrucción
    
    # Graficar la señal original y reconstruida
    plt.figure(figsize=(9, 4))
    plt.plot(señal_original, label='Señal Original', color='blue', alpha=0.7, linewidth=2)
    plt.plot(señal_reconstruida.flatten(), label='Señal Reconstruida', color='red', linestyle='dashed', alpha=0.7, linewidth=2)
    plt.title(f"Reconstrucción de la Señal - Índice: {indice}", fontsize=14)
    plt.xlabel("Índice de Característica", fontsize=12)
    plt.ylabel("Valor", fontsize=12)
    plt.legend(fontsize=10)
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
# Seleccionar una señal para visualizar
indice_señal = 10  # Cambia este índice para visualizar otras señales

# Llamar a la función de visualización
visualizar_reconstruccion(autoencoder, X_train_ae, indice_señal)

# %% [markdown]
# ## Visualizacion de espacios
# ### Espacio latente

# %%
# Crear el encoder como un modelo independiente
encoder = Model(inputs=autoencoder.input, outputs=autoencoder.get_layer('latent_space').output)

# Generar el espacio latente utilizando el encoder
espacio_latente = encoder.predict(X_train_ae)

# Verificar las dimensiones del espacio latente
print(f"Dimensiones de X_train_ae: {X_train_ae.shape}")
print(f"Dimensiones del espacio latente: {espacio_latente.shape}")
# Out:
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step
# Dimensiones de X_train_ae: (12408, 606)
# Dimensiones del espacio latente: (12408, 20)

# %%
# Guardar el encoder
encoder.save("../Modelos/Binary_Encoder_MPL_SS.keras")
print("Encoder guardado exitosamente.")
# Out:
# Encoder guardado exitosamente.

# %%
# Reducir el espacio latente a 2 dimensiones usando t-SNE
tsne = TSNE(n_components=2, random_state=42)
espacio_latente_2D = tsne.fit_transform(espacio_latente)

# %%
# Visualizar el espacio latente utilizando un scatter plot con mejoras
plt.figure(figsize=(9, 6))
colores = ['royalblue', 'darkorange']  # Colores para las clases

for i, clase in enumerate([0, 1]):
    indices = Y_train_ae == clase
    plt.scatter(
        espacio_latente_2D[indices, 0], 
        espacio_latente_2D[indices, 1], 
        label=f'Clase {clase}',
        alpha=0.4,  # Transparencia para observar superposición
        c=colores[i],
        edgecolor='w',  # Borde blanco para mayor claridad
        linewidth=0.5,
        s=30  # Tamaño de los puntos
    )

# Configuración del gráfico
plt.title("Espacio Latente (t-SNE)", fontsize=16, pad=15)
plt.xlabel("Componente 1", fontsize=12)
plt.ylabel("Componente 2", fontsize=12)
plt.legend(fontsize=12, loc='upper right')
plt.grid(visible=True, linestyle='--', alpha=0.5)  # Agregar una cuadrícula suave
plt.tight_layout()
plt.show()
